# %% [markdown]
# # 🚀 Tabular AutoML Pipeline — Production Workflow
#
# This notebook orchestrates a **production-grade supervised learning pipeline** using the centralized `AutoMLFactory` engine.
# All artifacts (models, plots, MLflow runs, predictions) are routed to a single run directory defined in the configuration.
#
# ---
#
# ### 📜 The Configuration Ledger (Schema)
#
# | Key | Type | Description | Available Options | Example |
# |:---|:---|:---|:---|:---|
# | `experiment_name` | `str` | MLflow experiment identifier. | Any string | `"Tabular_V2"` |
# | `task_type` | `str` | ML task routing. | `"tabular"` | `"tabular"` |
# | `dataset_path` | `str` | Path to cleaned CSV. | Any valid path | `"Dataset/train.csv"` |
# | `target_column` | `List[str]` | Target column name(s). Always a list, even for single-label. | Column name(s) in dataset | `["target"]` |
# | `problem_types` | `List[str]` | Problem type(s) per target. Leave `[]` for auto-inference. | `"binary"`, `"multiclass"`, `"regression"` | `[]` |
# | `eval_metrics` | `List[str]` | Optimization metric(s). One per target column. | **Binary/Multiclass:** `"f1_macro"`, `"f1_weighted"`, `"precision_macro"`, `"precision_weighted"`, `"recall_macro"`, `"recall_weighted"`, `"accuracy"` <br> **Regression:** `"mae"`, `"mape"`, `"rmse"`, `"mse"`, `"r2"` | `["f1"]` |
# | `presets` | `str` | AutoGluon v1.5 training preset. | `"extreme"`, `"best"`, `"high"`, `"medium"` | `"medium"` |
# | `time_limit_seconds` | `int` | Max training wall-clock time (sec). | Any positive integer | `600` |
# | `auto_stack` | `bool` | Enable multi-layer stacking. | `True`, `False` | `False` |
# | `calibrate_decision_threshold` | `bool` | Calibrate threshold (binary only). | `True`, `False` | `False` |
# | `multimodal_mode` | `bool` | Enable image/text routing. | `True`, `False` | `False` |
# | `image_column` | `str` | Column name for image paths. | Any column name | `"image_path"` |
# | `base_output_dir` | `str` | Centralized artifact output root. | Any valid directory path | `"tabular_run_v2"` |
# | `prediction_data_path` | `str` | Path to unseen data for batch inference. | Any valid path | `"Dataset/unseen.csv"` |
# | `fast_dev_run` | `bool` | Quick prototyping mode (subsamples data). | `True`, `False` | `True` |
# | `ai_context` | `str` | Business context string to guide the AI natural language report summary. | Any string, `None` | `"Predicting customer churn or loan defaults based on historical user features."` |
#
# ### ⚠️ Preset Guide
# | Preset | Quality | Speed | GPU Required | Notes |
# |:---|:---|:---|:---|:---|
# | `"extreme"` | ⭐⭐⭐⭐⭐ | Slow | **Yes** | Uses native AutoGluon Foundation Models (TabPFN, TabICL, Mitra, TabDPT, EBM) |
# | `"best"` | ⭐⭐⭐⭐ | Fast | No | Best quality (maps to `"best_v150"`, ~5x faster than legacy `best`) |
# | `"high"` | ⭐⭐⭐ | Fast | No | High quality (maps to `"high_v150"`, ~5x faster than legacy `high`) |
# | `"medium"` | ⭐⭐ | **Fastest** | No | Default. Ideal for initial prototyping |
#
# ### 🚫 Strict Rules
# 1. **Upstream Prerequisite**: Data must be fully cleaned (imputed, encoded, scaled) before ingestion.
# 2. **Preset Whitelist**: Only `extreme`, `best`, `high`, `medium` are accepted (best and high map to `best_v150` and `high_v150` under the hood). Others auto-fallback to `medium`.
# 3. **Foundation Models**: Accessed natively via the `extreme` preset (`pip install autogluon.tabular[tabarena]`). Custom wrappers are no longer used.
# 4. **GPU Awareness**: `extreme` preset requires a CUDA-capable GPU with 6+ GB VRAM for best foundation model performance.

# %% [markdown]
# ### 📋 Blank Configuration Template
#
# Copy this block and customize for your dataset:
#
# ```python
# AUTOML_CONFIG = {
#     # ── Core Pipeline Settings ──────────────────────────────────────
#     "experiment_name": "My_Experiment",
#     "task_type": "tabular",
#     "dataset_path": "Dataset/your_file.csv",
#     "target_column": ["your_target"],      # List[str] — always a list
#     "problem_types": [],                   # List[str] — leave [] for auto-inference
#
#     # ── Model Training & Metrics ────────────────────────────────────
#     "eval_metrics": ["f1"],                 # List[str] — one per target (see schema)
#     "presets": "medium",
#     "time_limit_seconds": 600,
#     "auto_stack": False,
#     "calibrate_decision_threshold": False,
#
#     # ── Multimodal (Optional Image/Text Features) ───────────────────
#     "multimodal_mode": False,
#     "image_column": None,
#
#     # ── Infrastructure & Inference ──────────────────────────────────
#     "base_output_dir": "automl_run",
#     "prediction_data_path": None,
#     "fast_dev_run": False,                  # Set False for production runs
#
#     # ── AI Audit Narrative ──────────────────────────────────────────
#     "ai_context": "Predicting customer churn or loan defaults based on historical user features."
# }
# ```

# %% [markdown]
# ---
# ## ⚙️ Step 1: Pipeline Configuration
# Customize the dictionary below for your dataset and experiment.

# %%
# ══════════════════════════════════════════════════════════════════════
#  Pipeline Configuration
# ══════════════════════════════════════════════════════════════════════

AUTOML_CONFIG = {
    # ── Core Pipeline Settings ──────────────────────────────────────
    "experiment_name": "tabular_run_v2",
    "task_type": "tabular",
    "dataset_path": "dummy_dataset/dummy_regression.csv",
    "target_column": ["target"],
    "problem_types": [],

    # ── Model Training & Metrics ────────────────────────────────────
    "eval_metrics": ["rmse"],         
    "presets": "Medium",              
    "time_limit_seconds": 200,
    "auto_stack": False,
    "calibrate_decision_threshold": False,

    # ── Multimodal (Optional Image/Text Features) ───────────────────
    "multimodal_mode": False,        # Use with CAUTION (it will be a long process)
    "image_column": None,

    # ── Infrastructure & Inference ──────────────────────────────────
    "base_output_dir": "tabular_run_v2",
    "prediction_data_path": "dummy_dataset/dummy_unseen.csv",
    "fast_dev_run": False,             

    # ── AI Audit Narrative ──────────────────────────────────────────
    "ai_context": "Predicting dummy dataset with numeric features and numeric target with no meaning at all."
}

# %% [markdown]
# ---
# ## 🏋️ Step 2: Model Training & Orchestration
# The engine handles hardware detection (GPU/CPU), train/test splitting, foundation model routing,
# ensemble construction, and MLflow telemetry automatically.

# %%
from ml_engine import AutoMLFactory

factory = AutoMLFactory(AUTOML_CONFIG)
factory.execute_pipeline()
# Out:
#         <style>
# @import url('https://fonts.googleapis.com/css2?family=Inter:wght@400;500;600;700&display=swap');
# @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono:wght@400;500&display=swap');
#
# /* ── Layout Shell ──────────────────────────────────────────────────── */
# .ml-wrap{--ap-bg:#0f172a;--ap-surface:#1e293b;--ap-border:#334155;--ap-text:#e2e8f0;--ap-accent:#38bdf8;--ap-radius:8px;font-family:'Inter',system-ui,-apple-system,sans-serif;color:#e2e8f0;max-width:1200px;margin:0 auto;line-height:1.5}
#
# /* ── Header ────────────────────────────────────────────────────────── */
# .ml-header{padding-bottom:16px;margin-bottom:20px;border-bottom:1px solid #334155;display:flex;align-items:center;justify-content:space-between;flex-wrap:wrap;gap:12px}
# .ml-title{font-size:1.6rem;font-weight:700;background:linear-gradient(135deg,#38bdf8,#a78bfa);-webkit-background-clip:text;-webkit-text-fill-color:transparent;margin:0}
# .ml-subtitle{font-size:.82rem;color:#64748b;margin:4px 0 0}
# .ml-header-pills{display:flex;gap:8px;flex-wrap:wrap}
# .ml-pill{display:inline-flex;align-items:center;gap:4px;padding:4px 10px;border-radius:20px;font-size:.7rem;font-weight:600;background:#1e293b;border:1px solid #334155;color:#94a3b8}
# .ml-pill .pill-val{color:#e2e8f0}
#
# /* ── Cards ─────────────────────────────────────────────────────────── */
# .ml-card{background:linear-gradient(135deg,#1e293b 0%,#0f172a 100%);border:1px solid #334155;border-radius:12px;padding:20px;margin-bottom:16px;backdrop-filter:blur(10px)}
# .ml-card h3{font-size:1rem;font-weight:600;color:#f1f5f9;margin:0 0 14px;display:flex;align-items:center;gap:8px}
#
# /* ── Metric Cards ──────────────────────────────────────────────────── */
# .ml-metrics{display:grid;grid-template-columns:repeat(auto-fit,minmax(140px,1fr));gap:10px;margin-bottom:14px;justify-content:center}
# .ml-metric{background:#0f172a;border:1px solid #1e293b;border-radius:10px;padding:14px;text-align:center;transition:border-color .2s,transform .2s}
# .ml-metric:hover{border-color:#475569;transform:translateY(-1px)}
# .ml-metric .val{font-size:1.3rem;font-weight:700;color:#f1f5f9;word-break:break-all}
# .ml-metric .lbl{font-size:.65rem;color:#64748b;text-transform:uppercase;letter-spacing:.05em;margin-top:4px}
# .ml-metric.green{border-color:#166534;background:linear-gradient(135deg,#052e16,#0f172a)}
# .ml-metric.green .val{color:#4ade80}
# .ml-metric.red{border-color:#991b1b;background:linear-gradient(135deg,#450a0a,#0f172a)}
# .ml-metric.red .val{color:#f87171}
# .ml-metric.blue{border-color:#1e40af;background:linear-gradient(135deg,#172554,#0f172a)}
# .ml-metric.blue .val{color:#60a5fa}
# .ml-metric.amber{border-color:#92400e;background:linear-gradient(135deg,#451a03,#0f172a)}
# .ml-metric.amber .val{color:#fbbf24}
# .ml-metric.cyan{border-color:#155e75;background:linear-gradient(135deg,#083344,#0f172a)}
# .ml-metric.cyan .val{color:#22d3ee}
# .ml-metric.purple{border-color:#6b21a8;background:linear-gradient(135deg,#3b0764,#0f172a)}
# .ml-metric.purple .val{color:#c084fc}
#
# /* ── Hero Metric Card (Best Model) ─────────────────────────────────── */
# .ml-metric-hero{background:linear-gradient(135deg,#1e3a5f 0%,#172554 50%,#0f172a 100%);border:2px solid #3b82f6;border-radius:12px;padding:18px;text-align:center;grid-column:1/-1;position:relative;overflow:hidden;box-shadow:0 0 20px #3b82f615}
# .ml-metric-hero::before{content:'';position:absolute;inset:0;background:linear-gradient(135deg,#3b82f618,transparent);pointer-events:none}
# .ml-metric-hero .val{font-size:1.15rem;font-weight:700;color:#60a5fa;word-break:break-all;position:relative}
# .ml-metric-hero .lbl{font-size:.72rem;color:#94a3b8;text-transform:uppercase;letter-spacing:.06em;margin-top:6px;font-weight:600;position:relative}
#
# /* ── Tables ────────────────────────────────────────────────────────── */
# .ml-tbl{width:100%;border-collapse:collapse;font-size:.8rem}
# .ml-tbl th{background:#1e293b;color:#94a3b8;font-weight:600;text-align:center;padding:8px 12px;border-bottom:2px solid #334155;font-size:.7rem;text-transform:uppercase;letter-spacing:.04em;position:sticky;top:0;z-index:10}
# .ml-tbl td{padding:8px 12px;border-bottom:1px solid #1e293b;color:#cbd5e1;text-align:center;vertical-align:middle}
# .ml-tbl tr:hover td{background:#1e293b80}
# .ml-tbl tr:first-child td{background:linear-gradient(90deg,#052e1640,transparent);font-weight:600}
# .ml-scroll-box{max-height:400px;overflow:auto;border:1px solid #334155;border-radius:8px;background:#0f172a}
#
# /* ── Two-Column Layout ─────────────────────────────────────────────── */
# .ml-grid-2{display:grid;grid-template-columns:1fr 1fr;gap:16px}
# @media(max-width:768px){.ml-grid-2{grid-template-columns:1fr}}
#
# /* ── Plot Gallery ──────────────────────────────────────────────────── */
# .ml-gallery{display:grid;grid-template-columns:repeat(auto-fit,minmax(420px,1fr));gap:16px;margin-top:12px}
# @media(max-width:500px){.ml-gallery{grid-template-columns:1fr}}
# .ml-gallery-item{background:#0f172a;padding:12px;border-radius:10px;border:1px solid #334155;text-align:center;transition:border-color .2s}
# .ml-gallery-item:hover{border-color:#475569}
# .ml-gallery-item img{max-width:100%;height:auto;border-radius:6px}
# .ml-gallery-item h4{margin:0 0 10px;color:#e2e8f0;font-size:.85rem;font-weight:600}
#
# /* ── Execution Log ─────────────────────────────────────────────────── */
# .ml-log-container{background:linear-gradient(145deg,#0f172a,#020617);border-radius:10px;border:1px solid #334155;overflow:hidden;box-shadow:0 10px 30px -5px rgba(0,0,0,0.6)}
# .ml-log-header{background:#1e293b;padding:10px 14px;display:flex;align-items:center;gap:8px;border-bottom:1px solid #0f172a}
# .ml-log-dot{width:11px;height:11px;border-radius:50%;box-shadow:inset 0 1px 2px rgba(255,255,255,0.1)}
# .ml-log-dot.r{background:#ef4444}
# .ml-log-dot.y{background:#eab308}
# .ml-log-dot.g{background:#22c55e}
# .ml-log-title{font-family:'Inter',sans-serif;font-size:0.75rem;color:#94a3b8;margin-left:10px;font-weight:600;letter-spacing:0.05em;display:flex;align-items:center;gap:6px;}
# .ml-log{font-family:'JetBrains Mono','Fira Code',monospace;padding:16px;font-size:.8rem;color:#e2e8f0;max-height:350px;overflow-y:auto;line-height:1.6}
# .ml-log .log-line{padding:4px 0;border-bottom:1px solid rgba(30,41,59,0.5);display:flex;gap:12px;transition:background 0.2s}
# .ml-log .log-line:hover{background:rgba(30,41,59,0.3)}
# .ml-log .log-time{color:#64748b;min-width:65px;font-size:0.75rem;padding-top:1px}
# .ml-log .log-prefix{color:#3b82f6;font-weight:500}
# .ml-log .log-warn{color:#fbbf24}
# .ml-log .log-err{color:#f87171;font-weight:bold}
#
# /* ── Accordion Sections ────────────────────────────────────────────── */
# details.ml-details{margin-bottom:12px}
# details.ml-details>summary{cursor:pointer;font-size:.95rem;font-weight:600;color:#e2e8f0;padding:12px 16px;background:linear-gradient(135deg,#1e293b,#0f172a);border:1px solid #334155;border-radius:8px;list-style:none;display:flex;align-items:center;gap:8px;transition:background .2s}
# details.ml-details>summary:hover{background:#1e293b}
# details.ml-details>summary::-webkit-details-marker{display:none}
# details.ml-details>summary::before{content:'▶';font-size:.7rem;color:#3b82f6;transition:transform .2s}
# details.ml-details[open]>summary::before{transform:rotate(90deg)}
# details.ml-details[open]>summary{border-radius:8px 8px 0 0;border-bottom:none}
# details.ml-details>.ml-details-body{padding:16px;background:linear-gradient(135deg,#1e293b 0%,#0f172a 100%);border:1px solid #334155;border-top:none;border-radius:0 0 12px 12px}
#
# /* ── Separator ─────────────────────────────────────────────────────── */
# .ml-sep{border:none;border-top:1px solid #334155;margin:20px 0}
#
# /* ── Status Badge ──────────────────────────────────────────────────── */
# .ml-status{display:inline-flex;align-items:center;gap:6px;padding:3px 10px;border-radius:20px;font-size:.72rem;font-weight:700}
# .ml-status.success{background:#052e16;color:#4ade80;border:1px solid #166534}
# .ml-status.running{background:#172554;color:#60a5fa;border:1px solid #1e40af}
#
# /* ── AI Narrative Gr

# %% [markdown]
# ---
# ## 🔧 Step 3: Post-Training Optimization for Deployment (Optional)
# If bagging or stacking was enabled, `refit_full()` re-trains the best model on 100% of the data.
# `persist()` loads models into RAM for faster inference. Only for server deployment. Update the engine first for this function.
#
# Documentation : https://auto.gluon.ai/stable/tutorials/tabular/advanced/tabular-deployment.html
#
# > **Note**: Only applicable when `num_bag_folds` or `auto_stack` were configured.

# %%
# Uncomment below for post-training optimization:
# factory._post_training_optimization()

# %% [markdown]
# ---
# ## ✅ Run Summary
#
# | Artifact | Location |
# |:---|:---|
# | Trained Models | `{base_output_dir}/models/` |
# | Visualization Plots | `{base_output_dir}/plots/` |
# | MLflow Tracking | `{base_output_dir}/mlruns/` |
# | Batch Predictions | `{base_output_dir}/predictions/` |
#
# All artifacts are portable. Copy the entire `base_output_dir` folder to share or deploy.
